# %%
import sys, os
import hydro
import daymetpy
import hydroeval as he
import hydrofunctions as hf
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd
import pickle5
import requests
import warnings
import numpy as np
from pandas.tseries.frequencies import to_offset
import logging
import matplotlib
# %matplotlib inline
plt.rcParams.update({'font.size': 14})
import matplotlib.gridspec as gridspec
import datetime
# %config InlineBackend.figure_format = 'retina'

# %%
class HydroException(Exception):
    """
        This is the base class for all exceptions created for the
        HydroFunctions package. This class is not meant to be raised.
    """

    pass

class HydroNoDataError(HydroException):
    """Raised when a service returns an empty dataset or indicates that\
        it has no data for the request.
        **Usage**::
            raise HydroNoDataError("The NWIS service had no data for this request.")
        Do not catch this error for interactive sessions: The user should
        get a useful message from the error when they try to request something
        that doesn't exist.
        Catch this error in automated systems so that the system can reconsider
        the request and either fix the request or move on to the next
        request.
        **Example**::
            try:
                hf.NWIS('666666666')
            except HydroNoDataError as err:
                print("This is just to illustrate how to capture this error.")
                print(err)
    """

    pass


"""
hydrofunctions.exceptions
~~~~~~~~~~~~~~~~~~~~~~~~~
This module contains all of the custom exceptions defined in this package. The
base class is HydroException and all custom exceptions are subclasses of
HydroException.
Use the errors like this::
    try:
        #some code here that might return no data
        #more code that might get encoded improperly
    except HydroNoDataError('This site has no data'):
        # handle error here.
    except HydroEncodeError():
        # handle this error here.
    else:
        # code to complete if there is no exception raised.
    finally:
        # code that you want to run whether an exception is raised or not.
        # If an exception wasn't caught, then this code gets run, and the
        # exception gets re-raised after this finally clause gets run.
Keep the try clause short: if you put too many things in there, it can be
difficult to figure out what broke. On the other hand, like in my example
above, it is more readable if you group a series of statements and then
handle their exceptions together.
**Example:**
    >>> raise HydroNoDataError("Oh no, NWIS doesn't have this data for you!")
https://axialcorps.com/2013/08/29/5-simple-rules-for-building-great-python-packages/
-----
"""
from __future__ import absolute_import, print_function, division, unicode_literals
import warnings


class HydroException(Exception):
    """
        This is the base class for all exceptions created for the
        HydroFunctions package. This class is not meant to be raised.
    """

    pass


class HydroNoDataError(HydroException):
    """Raised when a service returns an empty dataset or indicates that\
        it has no data for the request.
        **Usage**::
            raise HydroNoDataError("The NWIS service had no data for this request.")
        Do not catch this error for interactive sessions: The user should
        get a useful message from the error when they try to request something
        that doesn't exist.
        Catch this error in automated systems so that the system can reconsider
        the request and either fix the request or move on to the next
        request.
        **Example**::
            try:
                hf.NWIS('666666666')
            except HydroNoDataError as err:
                print("This is just to illustrate how to capture this error.")
                print(err)
    """

    pass


class HydroEncodeError(HydroException):
    """Raised when an error occurs while encoding or decoding an argument.
        **Example**::
            try:
                # bunch of code from your package
            except HydroException:
                # blanked condition to handle all errors from your package
    """

    pass


class HydroUserWarning(UserWarning):
    """Warn user of a hazardous condition or when an action has been triggered\
        that may be unexpected.
        This is the base class for all warnings created for the HydroFunctions
        package. This class can be used if there is no more specific warning
        available.
        **Usage**::
            import warnings
            ... code
            warnings.warn('This is my warning message.', HydroUserWarning)
        Note:
            Warnings can be hidden or turned off depending on how the user is
            accessing Python and the settings for their interface.
            Use HydroException if a process must be shut down, or is doomed to
            fail anyway. This will at least give the user a helpful error
            message.
    """

    pass

def get_nwis(
    site,
    service="dv",
    start_date=None,
    end_date=None,
    stateCd=None,
    countyCd=None,
    bBox=None,
    parameterCd="all",
    period=None,
):
    """Request stream gauge data from the USGS NWIS.
    Args:
        site (str or list of strings):
            a valid site is '01585200' or ['01585200', '01646502']. site
            should be `None` if stateCd or countyCd are not `None`.
        service (str):
            can either be 'iv' or 'dv' for instantaneous or daily data.
                - 'dv'(default): daily values. Mean value for an entire day.
                - 'iv': instantaneous value measured at this time. Also known\
                    as 'Real-time data'. Can be measured as often as every\
                    five minutes by the USGS. 15 minutes is more typical.
        start_date (str):
           should take on the form yyyy-mm-dd
        end_date (str):
            should take on the form yyyy-mm-dd
        stateCd (str):
            a valid two-letter state postal abbreviation. Default is `None`.
        countyCd (str or list of strings):
            a valid county abbreviation. Default is `None`.
        bBox (str, list, or tuple):
            a set of coordinates that defines a bounding box.
                * Coordinates are in decimal degrees
                * Longitude values are negative (west of the prime meridian).
                * Latitude values are positive (north of the equator).
                * comma-delimited, no spaces, if provided as a string.
                * The order of the boundaries should be: "West,South,East,North"
                * Example: "-83.000000,36.500000,-81.000000,38.500000"
        parameterCd (str or list of strings):
            NWIS parameter code. Usually a five digit code. Default is 'all'.\
            A valid code can also be given as a list: ``parameterCd=['00060','00065']``
                * if value of 'all' is submitted, then NWIS will return every \
                    parameter collected at this site. (default option)
                * stage: '00065'
                * discharge: '00060'
                * not all sites collect all parameters!
                * See https://nwis.waterdata.usgs.gov/usa/nwis/pmcodes for full list
        period (str):
            NWIS period code. Default is `None`.
                * Format is "PxxD", where xx is the number of days before today.
                * Either use start_date or period, but not both.
    Returns:
        a response object. This function will always return the response,
            even if the NWIS returns a status_code that indicates a problem.
            * response.url: the url we used to request data
            * response.json: the content translated as json
            * response.status_code: the internet status code
                - '200': is a good request
                - non-200 codes will be reported as a warning.
                - '400': is a 'Bad Request'-- the parameters did not make sense
                - see <https://www.w3.org/Protocols/rfc2616/rfc2616-sec10.html> for more codes and meaning.
            * response.ok: `True` when we get a '200' status_code
    Raises:
        ConnectionError: due to connection problems like refused connection
            or DNS Error.
        SyntaxWarning: when NWIS returns a response code that is not 200.
    **Example:**
        >>> import hydrofunctions as hf
        >>> response = hf.get_nwis('01585200', 'dv', '2012-06-01', '2012-07-01')
        >>> response
        <response [200]>
        >>> response.json()
        *JSON ensues*
        >>> hf.extract_nwis_df(response)
        *a Pandas dataframe appears*
    Other Valid Ways to Make a Request::
        >>> sites = ['07180500', '03380475', '06926000'] # Request a list of sites.
        >>> service = 'iv'  # Request real-time data
        >>> days = 'P10D'  # Request the last 10 days.
        >>> stage = '00065' # Sites that collect discharge usually collect water depth too.
        >>> response2 = hf.get_nwis(sites, service, period=days, parameterCd=stage)
    Request Data By Location::
        >>> # Request the most recent daily data for every site in Maine
        >>> response3 = hf.get_nwis(None, 'dv', stateCd='ME')
        >>> response3
        <Response [200]>
    The specification for the USGS NWIS IV service is located here:
    http://waterservices.usgs.gov/rest/IV-Service.html
    """

    service = check_NWIS_service(service)

    if parameterCd == "all":
        parameterCd = None

    header = {"Accept-encoding": "gzip", "max-age": "120"}

    values = {
        # specify version of nwis json. Based on WaterML1.1
        # json,1.1 works; json%2C works; json1.1 DOES NOT WORK
        "format": "json,1.1",
        "sites": check_parameter_string(site, "site"),
        "stateCd": stateCd,
        "countyCd": check_parameter_string(countyCd, "county"),
        "bBox": check_NWIS_bBox(bBox),
        "parameterCd": check_parameter_string(parameterCd, "parameterCd"),
        "period": period,
        "startDT": start_date,
        "endDT": end_date,
    }

#     # Check that site selection parameters are exclusive!
#     total = count_number_of_truthy([site, stateCd, countyCd, bBox])
#     if total == 1:
#         pass
#     elif total > 1:
#         raise ValueError(
#             "Select sites using either site, stateCd, "
#             "countyCd, or bBox, but not more than one."
#         )
#     elif total < 1:
#         raise ValueError(
#             "Select sites using at least one of the following "
#             "arguments: site, stateCd, countyCd or bBox."
#         )

    # Check that time parameters are not both set.
    # If neither is set, then NWIS will return the most recent observation.
    if start_date and period:
        raise ValueError(
            "Use either start_date or period, or neither, " "but not both."
        )

    if not (start_date or period):
        # User didn't specify time; must be requesting most recent data.
        # See issue #49.
        pass

    url = "https://waterservices.usgs.gov/nwis/"
    url = url + service + "/?"
    response = requests.get(url, params=values, headers=header)
    print("Requested data from", response.url)
    # requests will raise a 'ConnectionError' if the connection is refused
    # or if we are disconnected from the internet.

    # .get_nwis() will always return the response.

    # Higher-level code that calls get_nwis() may decide to handle or
    # report status codes that indicate something went wrong.

    # Issue warnings for bad status codes
    nwis_custom_status_codes(response)
    if not response.text:
        raise HydroNoDataError(
            "The NWIS has returned an empty string for this request."
        )

    return response

def check_NWIS_service(input):
    """Checks that the service is valid: either 'iv' or 'dv'"""
    if input is None:
        return None
    if input == "iv" or input == "dv":
        return input
    else:
        raise TypeError(
            "The NWIS service type accepts 'dv' for daily values, "
            "or 'iv' for instantaneous values. Actual value: "
            "{}".format(input)
        )
        
def check_parameter_string(candidate, param):
    """Checks that a parameter is a string or a list of strings.
    """
    parameters = {
        "site": "NWIS station id(s) should be a string or list of strings,"
        + "often in the form of an eight digit number enclosed in quotes.",
        "parameterCd": "NWIS parameter codes are five-digit strings that specify "
        + "the parameter that is being measured at the site. Common "
        + "codes are '00060' for stream stage in feet, '00065' for "
        + "stream discharge in cubic feet per second, and '72019' for "
        + "groundwater levels. Not all sites collect data for all "
        + "parameters. See a complete list of physical parameters here: "
        + "https://help.waterdata.usgs.gov/parameter_cd?group_cd=PHY "
        + "You may request multiple parameters by submitting a comma-"
        + "delimited string of codes with no spaces, or by submitting "
        + "a list of codes, like this: parameterCd = '00065,00060' or "
        + "parameterCd = ['00065', '00060'] ",
        "county": "The NWIS county parameter accepts a five-digit string or "
        + "a list of five-digit strings to select all of the sites "
        + "within a county or list of counties. "
        + "Example: '51059' or ['51059', '51061'] are acceptable.",
        "state": "This parameter uses US two-letter postal codes "
        + "such as 'MD' for Maryland or 'AZ' for Arizona.",
        "default": "This parameter should be a string or a list of strings.",
    }
    if param in parameters:
        msg = parameters[param] + " Actual value: {}".format(candidate)
    else:
        msg = (
            "This parameter should be a string or a list of strings."
            + " Actual value: {}".format(candidate)
        )

    if candidate is None:
        return None
    elif isinstance(candidate, str) and candidate:
        return candidate
    elif (isinstance(candidate, list) or isinstance(candidate, tuple)) and candidate:
        for s in candidate:
            if not isinstance(s, str):
                raise TypeError(msg + "   bad element: {}".format(s))
        return ",".join([str(s) for s in candidate])
    else:
        raise TypeError(msg)
        
def check_NWIS_bBox(input):
    """Checks that the USGS bBox is valid.
    """
    msg = (
        "NWIS bBox should be a string, list of strings, or tuple "
        + "containing the longitude and latitude of the lower left corner "
        + "of the bounding box, followed by the longitude and latitude "
        + "of the upper right corner of the bounding box. Most often in "
        + 'the form of "ll_long,ll_lat,ur_long,ur_lat" . '
        + "All latitude and longitude values should have less than 8 "
        + "places. "
        + "Actual value: {}".format(input)
    )
    if input is None:
        return None
    # assume that if it is a string it will be fine as is.
    # don't accept a series of sites in a single string.
    # Test for and reject empty strings: empty strings are false.
    if isinstance(input, str) and input:
        t = input.split(",")
        if len(t) < 4:
            raise TypeError(msg)
        return input
    # test for input is a list and it is not empty
    elif (isinstance(input, list) or isinstance(input, tuple)) and input:
        if len(input) < 4:
            raise TypeError(msg)
        # format:  [-83.000000, 36.500000, -81.000000, 38.500000] ==> '-83.000000,36.500000,-81.000000,38.500000'
        return ",".join([str(s) for s in input])
    else:
        raise TypeError(msg)

def count_number_of_truthy(my_list):
    return sum(bool(item) for item in my_list)

def nwis_custom_status_codes(response):
    """
    Raise custom warning messages from the NWIS when it returns a
    status_code that is not 200.
    Args:
        response: a response object as returned by get_nwis().
    Returns:
        * `None`
            if response.status_code == 200
        * `response.status_code`
            for all other status codes.
    Raises:
        SyntaxWarning: when a non-200 status code is returned.
            https://en.wikipedia.org/wiki/List_of_HTTP_status_codes
    Note:
        To raise an exception, call ``response.raise_for_status()``
        This will raise `requests.exceptions.HTTPError` with a helpful message
        or it will return `None` for status code 200.
        From: http://docs.python-requests.org/en/master/user/quickstart/#response-status-codes
        NWIS status_code messages come from:
            https://waterservices.usgs.gov/docs/portable_code.html
        Additional status code documentation:
            https://waterservices.usgs.gov/rest/IV-Service.html#Error
    """
    nwis_msg = {
        "200": "OK",
        "400": "400 Bad Request - "
        "This often occurs if the URL arguments "
        "are inconsistent. For example, if you submit a request using "
        "a startDT and an endDT with the period argument. "
        "An accompanying error should describe why the request was "
        "bad." + "\nError message from NWIS: {}".format(response.reason),
        "403": "403 Access Forbidden - "
        "This should only occur if for some reason the USGS has "
        "blocked your Internet Protocol (IP) address from using "
        "the service. This can happen if we believe that your use "
        "of the service is so excessive that it is seriously "
        "impacting others using the service. To get unblocked, "
        "send us the URL you are using along with the IP using "
        "this form. We may require changes to your query and "
        "frequency of use in order to give you access to the "
        "service again.",
        "404": "404 Not Found - "
        "Returned if and only if the query expresses a combination "
        "of elements where data do not exist. For multi-site "
        "queries, if any data are found, it is returned for those "
        "site/parameters/date ranges where there are data.",
        "503": "500 Internal Server Error - "
        "If you see this, it means there is a problem with the web "
        "service itself. It usually means the application server "
        "is down unexpectedly. This could be caused by a host of "
        "conditions, but changing your query will not solve this "
        "problem. The NWIS application support team has to fix it. Most "
        "of these errors are quickly detected and the support team "
        "is notified if they occur.",
    }
    if response.status_code == 200:
        return None
    # All other status codes will raise a warning.
    else:
        # Use the status_code as a key, return None if key not in dict
        msg = (
            "The NWIS returned a code of {}.\n".format(response.status_code)
            + nwis_msg.get(str(response.status_code))
            + "\n\nURL used in this request: {}".format(response.url)
        )

        # Warnings will not beak the flow. They just print a message.
        # However, they are often supressed in some applications.
        warnings.warn(msg, SyntaxWarning)
        return response.status_code
    
def extract_nwis_df(nwis_dict, interpolate=True):
    """Returns a Pandas dataframe and a metadata dict from the NWIS response
    object or the json dict of the response.
    Args:
        nwis_dict (obj):
            the json from a response object as returned by get_nwis().json().
            Alternatively, you may supply the response object itself.
    Returns:
        a pandas dataframe.
    Raises:
        HydroNoDataError
            when the request is valid, but NWIS has no data for
            the parameters provided in the request.
        HydroUserWarning
            when one dataset is sampled at a lower frequency than
            another dataset in the same request.
    """
    if type(nwis_dict) is not dict:
        nwis_dict = nwis_dict.json()

    # strip header and all metadata.
    ts = nwis_dict["value"]["timeSeries"]
    if ts == []:
        # raise a HydroNoDataError if NWIS returns an empty set.
        #
        # Ideally, an empty set exception would be raised when the request
        # is first returned, but I do it here so that the data doesn't get
        # extracted twice.
        # TODO: raise this exception earlier??
        #
        # ** Interactive sessions should have an error raised.
        #
        # **Automated systems should catch these errors and deal with them.
        # In this case, if NWIS returns an empty set, then the request
        # needs to be reconsidered. The request was valid somehow, but
        # there is no data being collected.

        raise HydroNoDataError(
            "The NWIS reports that it does not " "have any data for this request."
        )

    # create a list of time series;
    # set the index, set the data types, replace NaNs, sort, find the first and last

    collection = []
    starts = []
    ends = []
    freqs = []
    meta = {}
    for series in ts:
        series_name = series["name"]
        temp_name = series_name.split(":")
        agency = str(temp_name[0])
        site_id = agency + ":" + str(temp_name[1])
        parameter_cd = str(temp_name[2])
        stat = str(temp_name[3])
        siteName = series["sourceInfo"]["siteName"]
        siteLatLongSrs = series["sourceInfo"]["geoLocation"]["geogLocation"]
        noDataValues = series["variable"]["noDataValue"]
        variableDescription = series["variable"]["variableDescription"]
        unit = series["variable"]["unit"]["unitCode"]
        data = series["values"][0]["value"]
        if data == []:
            # This parameter has no data. Skip to next series.
            continue
        if len(data) == 1:
            # This parameter only contains the most recent reading.
            # See Issue #49
            pass
        qualifiers = series_name + "_qualifiers"
        DF = pd.DataFrame(data=data)
        DF.index = pd.to_datetime(DF.pop("dateTime"), utc=True)
        DF["value"] = DF["value"].astype(float)
        DF = DF.replace(to_replace=noDataValues, value=np.nan)
        DF["qualifiers"] = DF["qualifiers"].apply(lambda x: ",".join(x))
        DF.rename(
            columns={"qualifiers": qualifiers, "value": series_name}, inplace=True
        )
        DF.sort_index(inplace=True)
        local_start = DF.index.min()
        local_end = DF.index.max()
        starts.append(local_start)
        ends.append(local_end)
        local_freq = calc_freq(DF.index)
        freqs.append(local_freq)
        if not DF.index.is_unique:
            print(
                "Series index for "
                + series_name
                + " is not unique. Attempting to drop identical rows."
            )
            DF = DF.drop_duplicates(keep="first")
            if not DF.index.is_unique:
                print(
                    "Series index for "
                    + series_name
                    + " is STILL not unique. Dropping first rows with duplicated date."
                )
                DF = DF[~DF.index.duplicated(keep="first")]
        if local_freq > to_offset("0min"):
            local_clean_index = pd.date_range(
                start=local_start, end=local_end, freq=local_freq, tz="UTC"
            )
            # if len(local_clean_index) != len(DF):
            # This condition happens quite frequently with missing data.
            # print(str(series_name) + "-- clean index length: "+ str(len(local_clean_index)) + " Series length: " + str(len(DF)))
            DF = DF.reindex(index=local_clean_index, copy=True)
        else:
            # The dataframe DF must contain only the most recent data.
            pass
        qual_cols = DF.columns.str.contains("_qualifiers")
        # https://stackoverflow.com/questions/21998354/pandas-wont-fillna-inplace
        # Instead, create a temporary dataframe, fillna, then copy back into original.
        DFquals = DF.loc[:, qual_cols].fillna("hf.missing")
        DF.loc[:, qual_cols] = DFquals

        if local_freq > pd.Timedelta(to_offset("0min")):
            variableFreq_str = str(to_offset(local_freq))
        else:
            variableFreq_str = str(to_offset("0min"))
        parameter_info = {
            "variableFreq": variableFreq_str,
            "variableUnit": unit,
            "variableDescription": variableDescription,
        }
        site_info = {
            "siteName": siteName,
            "siteLatLongSrs": siteLatLongSrs,
            "timeSeries": {},
        }
        # if site is not in meta keys, add it.
        if site_id not in meta:
            meta[site_id] = site_info
        # Add the variable info to the site dict.
        meta[site_id]["timeSeries"][parameter_cd] = parameter_info
        collection.append(DF)

    if len(collection) < 1:
        # It seems like this condition should not occur. The NWIS trims the
        # response and returns an empty nwis_dict['value']['timeSeries']
        # if none of the parameters requested have data.
        # If at least one of the paramters have data,
        # then the empty series will get delivered, but with no data.
        # Compare these requests:
        # empty:               https://nwis.waterservices.usgs.gov/nwis/iv/?format=json&sites=01570500&startDT=2018-06-01&endDT=2018-06-01&parameterCd=00045
        # one empty, one full: https://nwis.waterservices.usgs.gov/nwis/iv/?format=json&sites=01570500&startDT=2018-06-01&endDT=2018-06-01&parameterCd=00045,00060
        raise HydroNoDataError(
            "The NWIS does not have any data for"
            " the requested combination of sites"
            ", parameters, and dates."
        )
    startmin = min(starts)
    endmax = max(ends)
    # Remove all frequencies of zero from freqs list.
    zero = to_offset("0min")
    freqs2 = list(filter(lambda x: x > zero, freqs))
    if len(freqs2) > 0:
        freqmin = min(freqs2)
        freqmax = max(freqs2)
        if freqmin != freqmax:
            warnings.warn(
                "One or more datasets in this request is going to be "
                "'upsampled' to " + str(freqmin) + " because the data "
                "were collected at a lower frequency of " + str(freqmax),
                HydroUserWarning,
            )

        clean_index = pd.date_range(start=startmin, end=endmax, freq=freqmin, tz="UTC")
        cleanDF = pd.DataFrame(index=clean_index)
        for dataset in collection:
            cleanDF = pd.concat([cleanDF, dataset], axis=1)
        # Replace lines with missing _qualifier flags with hf.upsampled
        qual_cols = cleanDF.columns.str.contains("_qualifiers")
        cleanDFquals = cleanDF.loc[:, qual_cols].fillna("hf.upsampled")
        cleanDF.loc[:, qual_cols] = cleanDFquals
        if interpolate:
            # TODO: mark interpolated values with 'hf.interp'
            # select data, then replace Nans with interpolated values.
            data_cols = cleanDF.columns.str.contains(r"[0-9]$")
            cleanDFdata = cleanDF.loc[:, data_cols].interpolate()
            cleanDF.loc[:, data_cols] = cleanDFdata
    else:
        # If datasets only contain most recent data, then
        # don't set an index or a freq. Just concat all of the datasets.
        cleanDF = pd.concat(collection, axis=1)

    cleanDF.index.name = "datetimeUTC"

    if not DF.index.is_unique:
        DF = DF[~DF.index.duplicated(keep="first")]
    if not DF.index.is_monotonic:
        DF.sort_index(axis=0, inplace=True)

    return cleanDF, meta

def calc_freq(index):
    # Method 0: calc_freq() was called, but we haven't done anything yet.
    method = 0
    if isinstance(index, pd.DataFrame):
        index = index.index
    try:
        # Method 1: Try the direct approach first. Maybe freq has already been set.
        freq = index.freq
        method = 1
    except AttributeError:
        # index.freq does not exist, so let's keep trying.
        freq = None

    if freq is None:
        # Method 2: Use the built-in pd.infer_freq(). It raises ValueError
        #    when it fails, so catch ValueErrors and keep trying.
        try:
            freq = to_offset(pd.infer_freq(index))
            method = 2
        except ValueError:
            pass

    if freq is None:
        # Method 3: divide the length of time by the number of observations.
        freq = (index.max() - index.min()) / len(index)
        if pd.Timedelta("13 minutes") < freq < pd.Timedelta("17 minutes"):
            freq = to_offset("15min")
        elif pd.Timedelta("27 minutes") < freq < pd.Timedelta("33 minutes"):
            freq = to_offset("30min")
        elif pd.Timedelta("55 minutes") < freq < pd.Timedelta("65 minutes"):
            freq = to_offset("60min")
        else:
            freq = None
        method = 3

    if freq is None:
        # Method 4: Subtract two adjacent values and use the difference!
        if len(index) > 3:
            freq = to_offset(abs(index[2] - index[3]))
            method = 4
            logging.debug(
                "calc_freq4:"
                + str(freq)
                + "= index[2]:"
                + str(index[3])
                + "- index [3]:"
                + str(index[2])
            )

    if freq is None:
        # Method 5: If all else fails, freq is 0 minutes!
        warnings.warn(
            "It is not possible to determine the frequency "
            "for one of the datasets in this request. "
            "This dataset will be set to a frequency of "
            "0 minutes",
            HydroUserWarning,
        )

        freq = to_offset("0min")
        method = 5

    debug_msg = "Calc_freq method:" + str(method) + "freq:" + str(freq)
    logging.debug(debug_msg)
    return pd.Timedelta(freq)

# %%
def NSE(simulated, observed):
    nse = 1-np.nansum((simulated-observed)**2)/np.nansum((observed-np.nanmean(observed))**2)
    return nse

def KGE(simulated, observed):
    sim_mean = np.mean(simulated, axis=0)
    obs_mean = np.mean(observed)

    r_num = np.sum((simulated - sim_mean) * (observed - obs_mean),
                   axis=0)
    r_den = np.sqrt(np.sum((simulated - sim_mean) ** 2,
                           axis=0)
                    * np.sum((observed - obs_mean) ** 2))
    r = r_num / r_den
    # calculate error in spread of flow alpha
    alpha = np.std(simulated, axis=0) / np.std(observed)
    # calculate error in volume beta (bias of mean discharge)
    beta = (np.sum(simulated, axis=0)
            / np.sum(observed))
    # calculate the Kling-Gupta Efficiency KGE
    kge_ = 1 - np.sqrt((r - 1) ** 2 + (alpha - 1) ** 2 + (beta - 1) ** 2)

    return (kge_, r, alpha, beta)

def RMSE(simulated, observed):
    rmse_ = np.sqrt(np.nanmean((observed - simulated) ** 2))
    return rmse_

def MARE(simulations, evaluation):
    mare_ = (np.sum(np.abs(evaluation - simulations), axis=0,)
             / np.sum(evaluation))
    return mare_

def Pbias(simulations, evaluation):
    pbias_ = (100 * np.sum(evaluation - simulations, axis=0)
              / np.sum(evaluation))
    return pbias_

def evaluate_performance(simulated, observed):
    nse = NSE(simulated,observed)
    kge, r, alpha, beta = KGE(simulated, observed)
    rmse = RMSE(simulated, observed)
    mare = MARE(simulated, observed)
    pbias = Pbias(simulated, observed)
    performance_dict = {'NSE':[nse], 'KGE':[(kge, r, alpha, beta)],
                       'RMSE':[rmse], 'MARE':[mare], 'Pbias':[pbias]}
    performance_df = pd.DataFrame.from_dict(performance_dict)
    return performance_df

def find_best(performance_df):
    best_nse = performance_df[performance_df.NSE>0.9*np.nanmax(performance_df.NSE)]
    best_nse_kge = best_nse[best_nse.KGE_only>0.9*np.nanmax(performance_df.KGE_only)]
    if len(best_nse_kge)==0:
        best_use = best_nse
        print('no good KGE, NSE overlap')
    else:
        best_nse_kge_rmse = best_nse_kge[best_nse_kge.RMSE<1.1*np.nanmin(performance_df.RMSE)]
        if len(best_nse_kge_rmse)==0:
            best_use = best_nse_kge
            print('no good KGE, NSE, RMSE overlap')
        else:
            best_nse_kge_rmse_mare = best_nse_kge_rmse[best_nse_kge_rmse.MARE<1.1*np.nanmin(performance_df.MARE)]
            if len(best_nse_kge_rmse_mare)==0:
                best_use = best_nse_kge_rmse
                print('no good KGE, NSE, RMSE, MARE overlap')
            else:
                best_use = best_nse_kge_rmse_mare
    return best_use

class HiddenPrints:
    def __enter__(self):
        self._original_stdout = sys.stdout
        sys.stdout = open(os.devnull, 'w')

    def __exit__(self, exc_type, exc_val, exc_tb):
        sys.stdout.close()
        sys.stdout = self._original_stdout

# %%
gridmet_tmin = pd.read_csv('Data/gridmet_Tmin_K_all_CONUS_gages.csv')
gridmet_tmin = gridmet_tmin.set_index(pd.to_datetime(gridmet_tmin['date'])).drop(columns='date')
gridmet_tmin = gridmet_tmin - 273.15 

gridmet_tmax = pd.read_csv('Data/gridmet_Tmax_K_all_CONUS_gages.csv')
gridmet_tmax = gridmet_tmax.set_index(pd.to_datetime(gridmet_tmax['date'])).drop(columns='date')
gridmet_tmax = gridmet_tmax - 273.15 

gridmet_prcp = pd.read_csv('Data/gridmet_P_mm_all_CONUS_gages2.csv')
gridmet_prcp = gridmet_prcp.set_index(pd.to_datetime(gridmet_prcp['date'])).drop(columns='date')

# %%
record_length = pd.read_csv('Data/record_length_yrs.csv')
gagesII = gpd.read_file('Data/gagesII_9322_point_shapefile/gagesII_9322_sept30_2011.shp')

# %%
limit=15
rlen = record_length[record_length.record_length_yr>limit]
errorsites = []

print('total: ',len(rlen))
for k in range(21,len(rlen)):
    sitenum = str(int(rlen.iloc[k].site))
    while len(sitenum)<8:
        sitenum = '0'+sitenum
    print('')
    print(k, sitenum)
    
    # download streamflow and water temperature data from NWIS
    try:
        state_temp= get_nwis(site=sitenum, service='iv', start_date='1950-01-01', end_date='2020-12-31',
                        parameterCd = '00010')
        state_temp = extract_nwis_df(state_temp)
        state_temp_meta = state_temp[1]
        state_temp = state_temp[0]
        state_temp = state_temp.rename(columns = {list(state_temp.columns)[0]:'temperature_C',
                                  list(state_temp.columns)[1]:'qualifiers'})

        state_data = get_nwis(site=sitenum, service='iv', start_date=str(state_temp.index[0])[:10], 
                              end_date=str(state_temp.index[-1])[:10],parameterCd = '00060')
        state_data = extract_nwis_df(state_data)
        state_data_meta = state_data[1]
        state_data = state_data[0]
        state_data = state_data.rename(columns = {list(state_data.columns)[0]:'discharge_cfs',
                                      list(state_data.columns)[1]:'qualifiers'})
        state_data = state_data.merge(state_temp,left_index=True, right_index=True)
    except:
        state_data = 'rats'
    if (len(state_data)==0) | (type(state_data) ==type('rats')):
        print('no data')
        errorsites.append(sitenum)
    else:
        state_data_day = state_data.resample('1D').mean()
        state_data_day['Tmin_water'] = state_data.temperature_C.resample('D').min()
        state_data_day['Tmax_water'] = state_data.temperature_C.resample('D').max()
        state_data_day = state_data_day.tz_convert(None)

        # call in gridmet data
        start = (state_temp.index[0]).tz_convert(None)
        end = (state_temp.index[-1]).tz_convert(None)
        if (pd.to_datetime('12-02-2020')-end).days<0:
            end = pd.to_datetime('12-02-2020')
        if (sitenum in gridmet_tmin.columns):
            site_gridmet_tmin = gridmet_tmin.rename(columns={sitenum:'tmin'})['tmin']
            site_gridmet_tmax = gridmet_tmax.rename(columns={sitenum:'tmax'})['tmax']
            try:
                site_gridmet_prcp = gridmet_prcp.rename(columns={sitenum[1:]:'prcp'})['prcp']
            except:
                site_gridmet_prcp = gridmet_prcp.rename(columns={sitenum:'prcp'})['prcp']
            site_gridmet = pd.DataFrame(site_gridmet_tmin).merge(site_gridmet_tmax,left_index=True,right_index=True)
            site_gridmet = site_gridmet.merge(site_gridmet_prcp,left_index=True,right_index=True)
            site_gridmet = site_gridmet.loc[start:end]
            state_data_day = state_data_day.merge(site_gridmet,left_index=True,right_index=True)        

            BFI_min = 0.1
            BFI_max = 0.9
            BFI_vals = np.linspace(BFI_min,BFI_max,200)
            # perform baseflow separation
            for BFI_val in BFI_vals:
                flowdata = hydro.Discharge(state_data_day.index, state_data_day.discharge_cfs, state_data_day.prcp)
                with HiddenPrints():
                    state_data_day['E_bflow'] = flowdata.Eckhardt(re=3, BFI = BFI_val)
                state_data_day['E_flashflow'] = state_data_day.discharge_cfs-state_data_day.E_bflow
                state_data_day['bflow_frac'] = state_data_day.E_bflow/state_data_day.discharge_cfs
                state_data_day['flashflow_frac'] = state_data_day.E_flashflow/state_data_day.discharge_cfs
                state_data_day['tmean'] = state_data_day[['tmin','tmax']].mean(axis=1)
                mean_temperature = np.nanmean(state_data_day.tmean)

                # calculate temperature timeseries from end-member mixing
                coldmonths = state_data_day.resample('30D').mean()
                coldmonths = coldmonths[coldmonths.tmean<np.nanmean(coldmonths.tmean)].reset_index()['index'].dt.month.drop_duplicates()
                state_data_day['tmild'] = np.where(state_data_day.reset_index()['index'].dt.month.isin(coldmonths), 
                                      state_data_day.tmax, state_data_day.tmin)
                state_data_day['tmild'] = state_data_day.tmild.ewm(span=120).mean()
                groundwater_temp = state_data_day.tmild
                guess = state_data_day.bflow_frac*groundwater_temp
                guessmin = guess + state_data_day.flashflow_frac*(state_data_day.tmean)
                guessmax = guess + state_data_day.flashflow_frac*(state_data_day.tmax)
                guessmean = guess + state_data_day.flashflow_frac*(state_data_day.tmean.rolling(2).mean())


                # calculate model efficiencies
                if BFI_val == BFI_min:
                    performance_min = evaluate_performance(guessmin,state_data_day.Tmin_water)
                    performance_max = evaluate_performance(guessmax,state_data_day.Tmax_water)
                    performance_mean = evaluate_performance(guessmean,state_data_day.temperature_C)
                    performance_rollingonly = evaluate_performance(groundwater_temp,state_data_day.temperature_C)
                else:
                    performance_min = pd.concat([performance_min,
                                                 evaluate_performance(guessmin,state_data_day.Tmin_water)])
                    performance_max = pd.concat([performance_max,
                                                 evaluate_performance(guessmax,state_data_day.Tmax_water)])
                    performance_mean = pd.concat([performance_mean,
                                                  evaluate_performance(guessmean,state_data_day.temperature_C)])
                    performance_rollingonly = pd.concat([performance_rollingonly,
                                                  evaluate_performance(groundwater_temp,state_data_day.temperature_C)])
            performance_mean = performance_mean.reset_index().drop(columns='index')
            performance_max = performance_max.reset_index().drop(columns='index')
            performance_min = performance_min.reset_index().drop(columns='index')
            performance_rollingonly = performance_rollingonly.reset_index().drop(columns='index')

            # find best BFI using performance on mean water temperature
            performance_mean['KGE_only'] = [performance_mean['KGE'].iloc[i][0] for i in range(len(performance_mean))]
            performance_min['KGE_only'] = [performance_min['KGE'].iloc[i][0] for i in range(len(performance_mean))]
            performance_max['KGE_only'] = [performance_max['KGE'].iloc[i][0] for i in range(len(performance_mean))]
            performance_rollingonly['KGE_only'] = [performance_rollingonly['KGE'].iloc[i][0] for i in range(len(performance_mean))]
            best_use_mean = find_best(performance_mean)
            best_use_max = find_best(performance_max)
            best_use_min = find_best(performance_min)
            if len(best_use_mean)==0:
                print('terrible performance')
            else:
                best_indices = [x for x in best_use_mean.index if x in best_use_min.index]
                if len(best_indices)==0:
                    best_indices = [x for x in best_use_mean.index if x in best_use_max.index]
                    if len(best_indices)==0:
                        best_index = int(best_use_mean[best_use_mean.NSE == np.nanmax(best_use_mean.NSE)].index.values)
                    else:
                        tmp = best_use_mean.loc[best_indices]
                        best_index = int(tmp[tmp.NSE == np.nanmax(tmp.NSE)].index.values)
                else:
                    best_indices1 = [x for x in best_indices if x in best_use_max.index]
                    if len(best_indices1)==0:
                        tmp = best_use_mean.loc[best_indices]
                        best_index = int(tmp[tmp.NSE == np.nanmax(tmp.NSE)].index.values)
                    else:
                        tmp = best_use_mean.loc[best_indices1]
                        best_index = int(tmp[tmp.NSE == np.nanmax(tmp.NSE)].index.values)

                # save that performance 
                best_BFI = float(BFI_vals[best_index])
                print('best BFI = ',best_BFI)


                save_best_info = {'mean_NSE':[performance_mean.loc[best_index].NSE],
                                  'max_NSE':[performance_max.loc[best_index].NSE],
                                  'min_NSE':[performance_min.loc[best_index].NSE],
                                  'rollingonly_NSE':[performance_rollingonly.loc[best_index].NSE],
                                  'mean_KGE':[performance_mean.loc[best_index].KGE_only],
                                  'max_KGE':[performance_max.loc[best_index].KGE_only],
                                 'min_KGE':[performance_min.loc[best_index].KGE_only], 
                                  'rollingonly_KGE':[performance_rollingonly.loc[best_index].KGE_only],
                                  'best_BFI':[best_BFI], 'sitenum':[sitenum]}
                print('model performance')
            #     print(save_best_info)
                if k==0:
                    best_info_total = pd.DataFrame.from_dict(save_best_info)
                else:
                    best_info_total = pd.concat([best_info_total,
                                                pd.DataFrame.from_dict(save_best_info)])

            #     except:
            #         print('no data')
            #         errorsites.append(sitenum)
                best_info_total.to_csv('end_member_model_performance.csv',index=False)
        else:
            print('no gridmet data')
            errorsites.append(sitenum)
#     except:
#         print('no data')
#         errorsites.append(sitenum)
# Out:
# total:  311
#
# 21 11251000
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11251000&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11251000&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# no good KGE, NSE overlap
# no good KGE, NSE overlap
# no good KGE, NSE overlap
# terrible performance
#
# 22 11257500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11257500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# no data
#
# 23 11261500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11261500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11261500&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.32512562814070356
# model performance
#
# 24 11274538
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11274538&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11274538&parameterCd=00060&startDT=2007-10-03&endDT=2018-11-19
# best BFI =  0.7834170854271357
# model performance
#
# 25 11276500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11276500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11276500&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# no good KGE, NSE overlap
# no good KGE, NSE overlap
# no good KGE, NSE overlap
# terrible performance
#
# 26 11276600
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11276600&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11276600&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# no good KGE, NSE overlap
# best BFI =  0.7311557788944724
# model performance
#
# 27 11289650
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11289650&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11289650&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# no good KGE, NSE overlap
# no good KGE, NSE overlap
# no good KGE, NSE overlap
# terrible performance
#
# 28 11302000
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11302000&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11302000&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# no data
#
# 29 11303000
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11303000&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11303000&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# no good KGE, NSE overlap
# best BFI =  0.5582914572864323
# model performance
#
# 30 11308900
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11308900&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# no data
#
# 31 11319500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11319500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# no data
#
# 32 11325500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11325500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# no data
#
# 33 11342000
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11342000&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# no data
#
# 34 11381500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11381500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11381500&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# no good KGE, NSE overlap
# no good KGE, NSE overlap
# best BFI =  0.4979899497487438
# model performance
#
# 35 11383500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11383500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11383500&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# no good KGE, NSE overlap
# best BFI =  0.514070351758794
# model performance
#
# 36 11388000
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11388000&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# no data
#
# 37 11390000
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11390000&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11390000&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# no good KGE, NSE overlap
# no good KGE, NSE overlap
# best BFI =  0.5904522613065327
# model performance
#
# 38 11390500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11390500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11390500&parameterCd=00060&startDT=2007-10-03&endDT=2021-01-01
# no good KGE, NSE overlap
# best BFI =  0.670854271356784
# model performance
#
# 39 11394500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11394500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# no data
#
# 40 11404500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11404500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# no data
#
# 41 11405300
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11405300&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# no data
#
# 42 11407000
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11407000&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# no data
#
# 43 11427000
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11427000&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# no data
#
# 44 11446500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11446500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11446500&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# no good KGE, NSE overlap
# no good KGE, NSE overlap
# no good KGE, NSE overlap
# terrible performance
#
# 45 11454000
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11454000&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# no data
#
# 46 11462500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11462500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11462500&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# no data
#
# 47 11463980
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11463980&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11463980&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# no data
#
# 48 11464000
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11464000&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# no data
#
# 49 11467000
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11467000&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11467000&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# no data
#
# 50 11467600
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11467600&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# no data
#
# 51 11470500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11470500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# no data
#
# 52 11477000
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11477000&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# no data
#
# 53 11480500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11480500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# no data
#
# 54 11516530
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11516530&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# no data
#
# 55 11520500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11520500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# no data
#
# 56 11523000
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11523000&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11523000&parameterCd=00060&startDT=2013-06-01&endDT=2021-01-01
# no good KGE, NSE overlap
# best BFI =  0.48190954773869354
# model performance
#
# 57 11530000
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11530000&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11530000&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# no good KGE, NSE overlap
# best BFI =  0.3613065326633166
# model performance
#
# 58 11532500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=11532500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# no data
#
# 59 06710000
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=06710000&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# no data
#
# 60 06711565
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=06711565&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=06711565&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.5462311557788945
# model performance
#
# 61 07086000
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=07086000&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=07086000&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# no data
#
# 62 07096000
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=07096000&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=07096000&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# no data
#
# 63 07097000
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=07097000&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=07097000&parameterCd=00060&startDT=1999-03-26&endDT=2021-01-01
# no good KGE, NSE overlap
# no good KGE, NSE overlap
# no good KGE, NSE overlap
# terrible performance
#
# 64 07099970
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=07099970&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=07099970&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# no good KGE, NSE overlap
# best BFI =  0.6467336683417085
# model performance
#
# 65 07106000
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=07106000&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=07106000&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.6105527638190955
# model performance
#
# 66 07106500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=07106500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=07106500&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.5180904522613066
# model performance
#
# 67 07109500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=07109500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=07109500&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.6185929648241206
# model performance
#
# 68 07119700
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=07119700&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=07119700&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# no data
#
# 69 07124000
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=07124000&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=07124000&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.4376884422110553
# model performance
#
# 70 07130500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=07130500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=07130500&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.1
# model performance
#
# 71 09095500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=09095500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=09095500&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.550251256281407
# model performance
#
# 72 09105000
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=09105000&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=09105000&parameterCd=00060&startDT=2007-10-01&endDT=2016-10-06
# best BFI =  0.4939698492462312
# model performance
#
# 73 09152500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=09152500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=09152500&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.6185929648241206
# model performance
#
# 74 09163500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=09163500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=09163500&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.5663316582914574
# model performance
#
# 75 09169500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=09169500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=09169500&parameterCd=00060&startDT=2007-12-13&endDT=2021-01-01
# best BFI =  0.3613065326633166
# model performance
#
# 76 09171100
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=09171100&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=09171100&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.34522613065326635
# model performance
#
# 77 09371492
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=09371492&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=09371492&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.2005025125628141
# model performance
#
# 78 09371520
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=09371520&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=09371520&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.46180904522613064
# model performance
#
# 79 02296750
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02296750&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# no data
#
# 80 02298202
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02298202&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02298202&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.2889447236180905
# model performance
#
# 81 02300021
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02300021&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02300021&parameterCd=00060&startDT=2007-10-01&endDT=2016-10-14
# no good KGE, NSE overlap
# no good KGE, NSE overlap
# no good KGE, NSE overlap
# terrible performance
#
# 82 02301719
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02301719&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02301719&parameterCd=00060&startDT=2007-10-01&endDT=2015-10-09
# no good KGE, NSE overlap
# no good KGE, NSE overlap
# no good KGE, NSE overlap
# terrible performance
#
# 83 02304510
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02304510&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02304510&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# no good KGE, NSE overlap
# no good KGE, NSE overlap
# no good KGE, NSE overlap
# terrible performance
#
# 84 02310650
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02310650&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02310650&parameterCd=00060&startDT=2007-10-13&endDT=2021-01-01
# no good KGE, NSE overlap
# no good KGE, NSE overlap
# no good KGE, NSE overlap
# terrible performance
#
# 85 02310700
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02310700&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02310700&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# no good KGE, NSE overlap
# no good KGE, NSE overlap
# no good KGE, NSE overlap
# terrible performance
#
# 86 02310747
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02310747&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02310747&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# no good KGE, NSE overlap
# no good KGE, NSE overlap
# no good KGE, NSE overlap
# terrible performance
#
# 87 02323592
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02323592&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02323592&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# no good KGE, NSE overlap
# no good KGE, NSE overlap
# no good KGE, NSE overlap
# terrible performance
#
# 88 02203655
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02203655&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02203655&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.550251256281407
# model performance
#
# 89 02203700
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02203700&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02203700&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.4658291457286433
# model performance
#
# 90 02204070
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02204070&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# no data
#
# 91 02207120
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02207120&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02207120&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.477889447236181
# model performance
#
# 92 02207185
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02207185&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02207185&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.6386934673366834
# model performance
#
# 93 02207385
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02207385&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02207385&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.6346733668341709
# model performance
#
# 94 02207400
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02207400&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02207400&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.578391959798995
# model performance
#
# 95 02208150
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02208150&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02208150&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.5542713567839197
# model performance
#
# 96 02217274
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02217274&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02217274&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.7150753768844221
# model performance
#
# 97 02218565
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02218565&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02218565&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.6025125628140704
# model performance
#
# 98 02330450
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02330450&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02330450&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.670854271356784
# model performance
#
# 99 02334430
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02334430&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02334430&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# no good KGE, NSE overlap
# no good KGE, NSE overlap
# no good KGE, NSE overlap
# terrible performance
#
# 100 02334480
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02334480&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02334480&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.6386934673366834
# model performance
#
# 101 02334578
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02334578&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02334578&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.6748743718592966
# model performance
#
# 102 02334885
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02334885&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02334885&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.6185929648241206
# model performance
#
# 103 02335000
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02335000&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02335000&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# no good KGE, NSE overlap
# no good KGE, NSE overlap
# no good KGE, NSE overlap
# terrible performance
#
# 104 02335350
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02335350&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02335350&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.5020100502512563
# model performance
#
# 105 02336030
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02336030&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02336030&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.6185929648241206
# model performance
#
# 106 02336120
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02336120&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02336120&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.4296482412060302
# model performance
#
# 107 02336240
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02336240&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02336240&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.4658291457286433
# model performance
#
# 108 02336300
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02336300&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02336300&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.3814070351758795
# model performance
#
# 109 02336360
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02336360&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02336360&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.4095477386934674
# model performance
#
# 110 02336410
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02336410&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02336410&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.43366834170854274
# model performance
#
# 111 02336526
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02336526&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02336526&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.4175879396984925
# model performance
#
# 112 02336728
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02336728&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02336728&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.4658291457286433
# model performance
#
# 113 02337170
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02337170&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02337170&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.7512562814070353
# model performance
#
# 114 02397000
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02397000&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02397000&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.6105527638190955
# model performance
#
# 115 12413370
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=12413370&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=12413370&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# no good KGE, NSE overlap
# best BFI =  0.7793969849246232
# model performance
#
# 116 12413445
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=12413445&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=12413445&parameterCd=00060&startDT=2007-10-01&endDT=2015-10-05
# best BFI =  0.9
# model performance
#
# 117 13340000
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=13340000&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=13340000&parameterCd=00060&startDT=2014-07-19&endDT=2021-01-01
# no good KGE, NSE overlap
# no good KGE, NSE overlap
# no good KGE, NSE overlap
# best BFI =  0.6989949748743719
# model performance
#
# 118 13340600
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=13340600&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=13340600&parameterCd=00060&startDT=2016-11-08&endDT=2021-01-01
# no good KGE, NSE overlap
# best BFI =  0.357286432160804
# model performance
#
# 119 13341050
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=13341050&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=13341050&parameterCd=00060&startDT=2008-02-01&endDT=2021-01-01
# no good KGE, NSE overlap
# no good KGE, NSE overlap
# no good KGE, NSE overlap
# terrible performance
#
# 120 13342500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=13342500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=13342500&parameterCd=00060&startDT=2013-09-13&endDT=2021-01-01
# no good KGE, NSE overlap
# no good KGE, NSE overlap
# no good KGE, NSE overlap
# terrible performance
#
# 121 03323500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=03323500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# no data
#
# 122 03373980
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=03373980&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=03373980&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.642713567839196
# model performance
#
# 123 03374500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=03374500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# no data
#
# 124 05454500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=05454500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# no data
#
# 125 05455000
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=05455000&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# no data
#
# 126 05462000
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=05462000&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# no data
#
# 127 05465500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=05465500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=05465500&parameterCd=00060&startDT=2011-10-01&endDT=2018-04-23
# best BFI =  0.44170854271356785
# model performance
#
# 128 05474000
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=05474000&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# no data
#
# 129 07144100
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=07144100&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=07144100&parameterCd=00060&startDT=2007-10-01&endDT=2019-07-15
# no data
#
# 130 07144780
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=07144780&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=07144780&parameterCd=00060&startDT=2007-10-01&endDT=2017-06-07
# best BFI =  0.4537688442211055
# model performance
#
# 131 01095220
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=01095220&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=01095220&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.36532663316582914
# model performance
#
# 132 01095375
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=01095375&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=01095375&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.2809045226130653
# model performance
#
# 133 01104430
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=01104430&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=01104430&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.7311557788944724
# model performance
#
# 134 01104460
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=01104460&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=01104460&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.5341708542713568
# model performance
#
# 135 01104475
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=01104475&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=01104475&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.7512562814070353
# model performance
#
# 136 04043238
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=04043238&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=04043238&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.8236180904522613
# model performance
#
# 137 04043244
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=04043244&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=04043244&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.8195979899497488
# model performance
#
# 138 04121944
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=04121944&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=04121944&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.6105527638190955
# model performance
#
# 139 04121970
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=04121970&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=04121970&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.6628140703517589
# model performance
#
# 140 04124000
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=04124000&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=04124000&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.7110552763819096
# model performance
#
# 141 04124200
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=04124200&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=04124200&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.7190954773869347
# model performance
#
# 142 04125460
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=04125460&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=04125460&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.7954773869346734
# model performance
#
# 143 04125550
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=04125550&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=04125550&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.6949748743718593
# model performance
#
# 144 04136000
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=04136000&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=04136000&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.7030150753768845
# model performance
#
# 145 04136500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=04136500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=04136500&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.6748743718592966
# model performance
#
# 146 04136900
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=04136900&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=04136900&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.6748743718592966
# model performance
#
# 147 04137005
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=04137005&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=04137005&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.6587939698492463
# model performance
#
# 148 04137500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=04137500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=04137500&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.5984924623115578
# model performance
#
# 149 06894000
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=06894000&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=06894000&parameterCd=00060&startDT=2007-10-03&endDT=2020-12-30
# best BFI =  0.32512562814070356
# model performance
#
# 150 07061270
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=07061270&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=07061270&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.5944723618090453
# model performance
#
# 151 06041000
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=06041000&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=06041000&parameterCd=00060&startDT=2009-01-02&endDT=2021-01-01
# best BFI =  0.7311557788944724
# model performance
#
# 152 06054500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=06054500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=06054500&parameterCd=00060&startDT=2011-10-01&endDT=2021-01-01
# best BFI =  0.40552763819095483
# model performance
#
# 153 06066500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=06066500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=06066500&parameterCd=00060&startDT=2011-10-01&endDT=2021-01-01
# best BFI =  0.799497487437186
# model performance
#
# 154 12323770
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=12323770&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=12323770&parameterCd=00060&startDT=2011-10-01&endDT=2021-01-01
# best BFI =  0.7271356783919598
# model performance
#
# 155 06465500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=06465500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=06465500&parameterCd=00060&startDT=2010-10-11&endDT=2021-01-01
# best BFI =  0.6668341708542714
# model performance
#
# 156 06775500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=06775500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# no data
#
# 157 06881000
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=06881000&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# no data
#
# 158 10301500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=10301500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=10301500&parameterCd=00060&startDT=2012-02-06&endDT=2021-01-01
# best BFI =  0.4015075376884423
# model performance
#
# 159 10348200
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=10348200&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=10348200&parameterCd=00060&startDT=2013-10-01&endDT=2021-01-01
# best BFI =  0.514070351758794
# model performance
#
# 160 10351650
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=10351650&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# no data
#
# 161 10351700
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=10351700&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=10351700&parameterCd=00060&startDT=2012-05-17&endDT=2021-01-01
# best BFI =  0.5542713567839197
# model performance
#
# 162 01388000
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=01388000&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=01388000&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.1120603015075377
# model performance
#
# 163 01463500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=01463500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=01463500&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.3331658291457287
# model performance
#
# 164 01466500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=01466500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=01466500&parameterCd=00060&startDT=2012-02-08&endDT=2020-12-31
# best BFI =  0.8798994974874372
# model performance
#
# 165 08317400
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=08317400&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=08317400&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# no good KGE, NSE overlap
# best BFI =  0.578391959798995
# model performance
#
# 166 01362500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=01362500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# ...
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02156500&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# Series index for USGS:02156500:00060:00000 is not unique. Attempting to drop identical rows.
# best BFI =  0.4095477386934674
# model performance
#
# 264 02160105
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02160105&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02160105&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.33718592964824123
# model performance
#
# 265 02160700
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02160700&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02160700&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.44170854271356785
# model performance
#
# 266 02163001
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02163001&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02163001&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.5301507537688442
# model performance
#
# 267 02168504
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02168504&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02168504&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# no good KGE, NSE overlap
# no good KGE, NSE overlap
# no good KGE, NSE overlap
# terrible performance
#
# 268 02169000
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02169000&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02169000&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# no good KGE, NSE overlap
# no good KGE, NSE overlap
# no good KGE, NSE overlap
# terrible performance
#
# 269 03428200
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=03428200&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# no data
#
# 270 03597860
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=03597860&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=03597860&parameterCd=00060&startDT=2007-10-01&endDT=2012-10-01
# best BFI =  0.5824120603015076
# model performance
#
# 271 07227500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=07227500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=07227500&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.30100502512562816
# model performance
#
# 272 07311782
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=07311782&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=07311782&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# no data
#
# 273 07312100
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=07312100&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# no data
#
# 274 07312500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=07312500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=07312500&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.34522613065326635
# model performance
#
# 275 08049500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=08049500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=08049500&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.6105527638190955
# model performance
#
# 276 08062500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=08062500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=08062500&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.5864321608040202
# model performance
#
# 277 08065350
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=08065350&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=08065350&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.3773869346733668
# model performance
#
# 278 08068400
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=08068400&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# no data
#
# 279 08068500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=08068500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=08068500&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.29296482412060304
# model performance
#
# 280 08070200
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=08070200&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=08070200&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.37336683417085426
# model performance
#
# 281 08123800
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=08123800&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# no data
#
# 282 08123850
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=08123850&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=08123850&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.3814070351758795
# model performance
#
# 283 08181500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=08181500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=08181500&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.707035175879397
# model performance
#
# 284 08181800
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=08181800&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=08181800&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.7351758793969849
# model performance
#
# 285 09234500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=09234500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=09234500&parameterCd=00060&startDT=2004-02-05&endDT=2021-01-01
# no data
#
# 286 09302000
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=09302000&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=09302000&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.5864321608040202
# model performance
#
# 287 09406000
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=09406000&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=09406000&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.5422110552763819
# model performance
#
# 288 10129900
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=10129900&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=10129900&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.7834170854271357
# model performance
#
# 289 10133800
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=10133800&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=10133800&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.4256281407035176
# model performance
#
# 290 02011400
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02011400&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02011400&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.25678391959798996
# model performance
#
# 291 02011500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02011500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02011500&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.2809045226130653
# model performance
#
# 292 02011800
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02011800&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02011800&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.9
# model performance
#
# 293 02012500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02012500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02012500&parameterCd=00060&startDT=2020-03-11&endDT=2021-01-01
# no data
#
# 294 02035000
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02035000&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=02035000&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.1
# model performance
#
# 295 03176500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=03176500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# no data
#
# 296 12011500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=12011500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# no data
#
# 297 12116500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=12116500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=12116500&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.48994974874371866
# model performance
#
# 298 12117600
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=12117600&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=12117600&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# no good KGE, NSE overlap
# best BFI =  0.7592964824120604
# model performance
#
# 299 12119000
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=12119000&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=12119000&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.6346733668341709
# model performance
#
# 300 12147500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=12147500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=12147500&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# no good KGE, NSE overlap
# best BFI =  0.7633165829145729
# model performance
#
# 301 12147600
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=12147600&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=12147600&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.578391959798995
# model performance
#
# 302 12148000
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=12148000&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=12148000&parameterCd=00060&startDT=2007-10-02&endDT=2021-01-01
# best BFI =  0.8155778894472362
# model performance
#
# 303 12148300
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=12148300&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=12148300&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.7552763819095478
# model performance
#
# 304 01595200
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=01595200&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# no data
#
# 305 01608500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=01608500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=01608500&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# best BFI =  0.1
# model performance
#
# 306 03195500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=03195500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# no data
#
# 307 05430500
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=05430500&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# no data
#
# 308 05435943
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=05435943&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=05435943&parameterCd=00060&startDT=2007-10-01&endDT=2021-01-01
# no good KGE, NSE overlap
# best BFI =  0.8798994974874372
# model performance
#
# 309 06036905
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=06036905&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=06036905&parameterCd=00060&startDT=2011-10-01&endDT=2021-01-01
# no good KGE, NSE overlap
# no good KGE, NSE overlap
# no good KGE, NSE overlap
# terrible performance
#
# 310 09217000
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=09217000&parameterCd=00010&startDT=1950-01-01&endDT=2020-12-31
# Requested data from https://nwis.waterservices.usgs.gov/nwis/iv/?format=json%2C1.1&sites=09217000&parameterCd=00060&startDT=2007-10-01&endDT=2020-10-01
# best BFI =  0.8115577889447236
# model performance

# %%
fig, ax = plt.subplots(2,3,figsize = (15,8))

ax0 = ax[0][0]
best_info_total.mean_NSE.hist(edgecolor='k',bins = np.linspace(0,1,11),ax = ax0)
ax0.set_title('Mean daily water temperature')
ax0.set_ylabel('Number of stations')
ax0.set_xlabel('NSE')
ax0.set_ylim(0,70)

ax1 = ax[1][0]
best_info_total.mean_KGE.hist(edgecolor = 'k',bins = np.linspace(0,1,11),ax=ax1,facecolor='skyblue')
ax1.set_ylabel('Number of stations')
ax1.set_xlabel('KGE')
ax1.set_ylim(0,90)

ax0 = ax[0][1]
best_info_total.max_NSE.hist(edgecolor='k',bins = np.linspace(0,1,11),ax = ax0)
ax0.set_title('Max. daily water temperature')
# ax0.set_ylabel('Number of stations')
ax0.set_xlabel('NSE')
ax0.set_ylim(0,70)

ax1 = ax[1][1]
best_info_total.max_KGE.hist(edgecolor = 'k',bins = np.linspace(0,1,11),ax=ax1,facecolor='skyblue')
# ax1.set_ylabel('Number of stations')
ax1.set_xlabel('KGE')
ax1.set_ylim(0,90)

ax0 = ax[0][2]
# best_info_total.min_NSE.hist(edgecolor='k',bins = np.linspace(0,1,11),ax = ax0)
ax0.set_title('Min. daily water temperature')
# ax0.set_ylabel('Number of stations')
ax0.set_xlabel('NSE')
ax0.set_ylim(0,70)

ax1 = ax[1][2]
best_info_total.min_KGE.hist(edgecolor = 'k',bins = np.linspace(0,1,11),ax=ax1,facecolor='skyblue')
# ax1.set_ylabel('Number of stations')
ax1.set_xlabel('KGE')
ax1.set_ylim(0,90)
# Out:
# (0.0, 90.0)

# %%
fit_threshold = 0.6
print('total number of sites:',len(best_info))
print('number of sites with mean temp KGE>0.6:',len(best_info[best_info.mean_KGE>fit_threshold]))
print('number of sites all KGE>0.6:',len(best_info[(best_info.mean_KGE>fit_threshold) &
                                                  (best_info.max_KGE>fit_threshold) &
                                                  (best_info.min_KGE>fit_threshold)]))
print('number of reference sites:',len(best_info_ref))
print('number of reference sites with all KGE>0.6:',len(best_info_ref[(best_info_ref.mean_KGE>fit_threshold) &
                                                  (best_info_ref.max_KGE>fit_threshold) &
                                                  (best_info_ref.min_KGE>fit_threshold)]))
# Out:
# total number of sites: 201
# number of sites with mean temp KGE>0.6: 191
# number of sites all KGE>0.6: 137
# number of reference sites: 31
# number of reference sites with all KGE>0.6: 14

# %%
best_info = best_info_total.merge(gagesII[['STAID','geometry','LAT_GAGE','LNG_GAGE','CLASS']],
                                  left_on='sitenum',
                                 right_on='STAID',how='left')
best_info = gpd.GeoDataFrame(best_info, geometry = best_info.geometry)
state_outline = gpd.read_file('../NaturalCommunity/US_state_outline/cb_2018_us_state_500k.shp').to_crs(epsg=4326)
gagesII = gagesII.to_crs(epsg=4326)

# %%
fig,ax = plt.subplots(3,figsize =(15,18))
for i in range(3):
    state_outline.plot(facecolor='white',edgecolors = 'k', ax=ax[i])
    ax[i].set_xlim(-130,-65)
    ax[i].set_ylim(22,50)
    ax[i].set_xticks([])
    ax[i].set_yticks([])

cmap_use = 'YlGnBu'#'magma'
best_info_ref = best_info[best_info.CLASS=='Ref']
best_info_nonref = best_info[best_info.CLASS=='Non-ref']
    
ax0=ax[0]
im = ax0.scatter(best_info_nonref.LNG_GAGE,best_info_nonref.LAT_GAGE, c=best_info_nonref.mean_KGE,
           cmap = cmap_use,vmin = 0, vmax = 1, edgecolor = 'white', s=200, label = 'non-reference')
ax0.scatter(best_info_ref.LNG_GAGE,best_info_ref.LAT_GAGE, c=best_info_ref.mean_KGE,
           cmap = cmap_use,vmin = 0, vmax = 1, edgecolor = 'white', s=500, label = 'reference',
                marker = '*')
ax0.set_title('Mean stream water temperature')

ax0 = ax[1]
ax0.scatter(best_info_nonref.LNG_GAGE,best_info_nonref.LAT_GAGE, c=best_info_nonref.max_KGE,
           cmap = cmap_use,vmin = 0, vmax = 1, edgecolor = 'white', s=200, label = 'non-reference')
ax0.scatter(best_info_ref.LNG_GAGE,best_info_ref.LAT_GAGE, c=best_info_ref.mean_KGE,
           cmap = cmap_use,vmin = 0, vmax = 1, edgecolor = 'white', s=500, label = 'reference',
                marker = '*')
ax0.set_title('Max. stream water temperature')

ax0 = ax[2]
ax0.scatter(best_info_nonref.LNG_GAGE,best_info_nonref.LAT_GAGE, c=best_info_nonref.max_KGE,
           cmap = cmap_use,vmin = 0, vmax = 1, edgecolor = 'white', s=200, label = 'non-reference')
ax0.scatter(best_info_ref.LNG_GAGE,best_info_ref.LAT_GAGE, c=best_info_ref.mean_KGE,
           cmap = cmap_use,vmin = 0, vmax = 1, edgecolor = 'white', s=500, label = 'reference',
                marker = '*')
ax0.set_title('Min. stream water temperature')

cols = ['mean_KGE','max_KGE','min_KGE']
for i in range(3):
    allgoodref = best_info_ref[(best_info_ref.mean_KGE>fit_threshold) &
                       (best_info_ref.max_KGE>fit_threshold) &
                       (best_info_ref.min_KGE>fit_threshold)]
    allgoodnoref = best_info_nonref[(best_info_nonref.mean_KGE>fit_threshold) &
                       (best_info_nonref.max_KGE>fit_threshold) &
                       (best_info_nonref.min_KGE>fit_threshold)]
    ax[i].scatter(allgoodref.LNG_GAGE,allgoodref.LAT_GAGE, c = None, edgecolor = 'firebrick',
                 s=500, lw = 2, marker = '*')
    ax[i].scatter(allgoodnoref.LNG_GAGE,allgoodnoref.LAT_GAGE, edgecolor = 'firebrick',
                 s=200, lw = 2, c = allgoodnoref[cols[i]], cmap = cmap_use,vmin = 0,vmax=1)

ax[0].legend(frameon=False, loc = 'lower left')
fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.85, 0.15, 0.05, 0.7])
cbar = fig.colorbar(im, cax=cbar_ax)
cbar.ax.set_ylabel('KGE')
# Out:
# Text(0, 0.5, 'KGE')

# %%
fig, ax = plt.subplots(1,2,figsize = (12,5))

ax0 = ax[0]
ax0.axvspan(0.6,1,facecolor = 'k',alpha = 0.1)
ax0.axhspan(0.6,1,facecolor = 'k',alpha = 0.1)
ax0.scatter(best_info.max_KGE,best_info.mean_KGE)

ax1 = ax[1]
ax1.axvspan(0.6,1,facecolor = 'k',alpha = 0.1)
ax1.axhspan(0.6,1,facecolor = 'k',alpha = 0.1)
ax1.scatter(best_info.min_KGE,best_info.mean_KGE)

ax0.set_ylabel('mean temp. KGE')
ax0.set_xlabel('max. temp. KGE')
ax1.set_xlabel('min. temp. KGE')

for i in range(2):
    ax[i].set_xlim(0,1)
    ax[i].set_ylim(0,1)

# %%
fig, ax = plt.subplots(1,figsize = (12,6))

state_outline.plot(facecolor='white',edgecolors = 'k', ax=ax)
ax.set_xlim(-130,-65)
ax.set_ylim(22,50)
ax.set_xticks([])
ax.set_yticks([])

ax.scatter(best_info_ref.LNG_GAGE,
          best_info_ref.LAT_GAGE, s=500, c = 'coral',marker = '*',
          edgecolor = 'k', label ='reference gauge with {:1.0f}+ years continous stream temperature record'.format(limit))

ax.scatter(allgoodref[allgoodref.CLASS=='Ref'].LNG_GAGE,
          allgoodref[allgoodref.CLASS=='Ref'].LAT_GAGE, s=500, c = 'firebrick',marker = '*',
          edgecolor = 'k', label = 'reference gauge, KGE>{:1.1f} for mean, min, and max stream temperature'.format(fit_threshold))

ax.legend(frameon=False,loc='lower left')

# %%
fig, ax = plt.subplots(1,figsize = (16,8))
cmap_use1 = 'viridis'

state_outline.plot(facecolor='white',edgecolors = 'k', ax=ax)
ax.set_xlim(-130,-65)
ax.set_ylim(22,50)
ax.set_xticks([])
ax.set_yticks([])


# ax.scatter(best_info_nonref.LNG_GAGE, best_info_nonref.LAT_GAGE, s=200, c=best_info_nonref.best_BFI, 
#           vmin = 0., vmax = 1, cmap = cmap_use1, edgecolor = 'k', 
#            label = 'Non-ref. gauge with {:1.0f}+ years continuous stream temperature record'.format(limit))

ax.scatter(allgoodnoref.LNG_GAGE, allgoodnoref.LAT_GAGE, s=200, c=allgoodnoref.best_BFI, 
          vmin = 0., vmax = 1, cmap = cmap_use1, edgecolor = 'k',#edgecolor = 'firebrick',lw = 2, 
           label = 'Non-ref. gauge with, KGE>{:1.1f} for mean, min, and max stream temperature'.format(fit_threshold))

# cm = ax.scatter(best_info_ref.LNG_GAGE,
#           best_info_ref.LAT_GAGE, s=500, c = best_info_ref.best_BFI,marker = '*',vmin = 0., vmax = 1,cmap = cmap_use1,
#           edgecolor = 'k', label ='reference gauge with {:1.0f}+ years continous stream temperature record'.format(limit))

ax.scatter(allgoodref[allgoodref.CLASS=='Ref'].LNG_GAGE,
          allgoodref[allgoodref.CLASS=='Ref'].LAT_GAGE, s=500, c = allgoodref.best_BFI,
           vmin = 0., vmax = 1, cmap = cmap_use1, marker = '*',edgecolor = 'k',
#           edgecolor = 'firebrick', lw=2, 
           label = 'reference gauge, KGE>{:1.1f} for mean, min, and max stream temperature'.format(fit_threshold))


ax.legend(frameon=False,loc='lower left')

fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.85, 0.15, 0.05, 0.7])
cbar = fig.colorbar(cm, cax=cbar_ax)
cbar.ax.set_ylabel('BFI')
# Out:
# Text(0, 0.5, 'BFI')

# %%
fig, ax = plt.subplots(1,figsize = (16,8))
state_outline.plot(facecolor='white',edgecolors = 'k', ax=ax)
ax.set_xlim(-130,-65)
ax.set_ylim(22,50)
ax.set_xticks([])
ax.set_yticks([])

gagesII[gagesII.CLASS=='Ref'].plot(ax = ax, c='k')
# Out:
# <AxesSubplot:>

# %%
# trashed model ideas

# use daymet data
lon = float(gagesII[gagesII.STAID==sitenum].LNG_GAGE)
        lat = float(gagesII[gagesII.STAID==sitenum].LAT_GAGE)
        start = int(str(state_temp.index[0])[:4])
        end = int(str(state_temp.index[-1])[:4])
        if end==2021:
            end = 2020
        site_daymet = daymetpy.daymet_timeseries(lon=lon, lat=lat, start_year=start, end_year=end)
        site_daymet = site_daymet.loc[state_temp.index[0]:state_temp.index[-1]]
        site_daymet = site_daymet.tz_localize(None)
        state_data_day = state_data_day.merge(site_daymet,left_index=True,right_index=True)

# calculate annual groundwater pattern
        smoothed = state_data.temperature_C.rolling(24*28*2).mean().resample('D').mean().tz_convert(None)
        maxtemp = []
        maxdates = []
        mintemp = []
        mindates = []
        for yr in smoothed.reset_index().datetimeUTC.dt.year.drop_duplicates():
            summer = smoothed.loc[pd.to_datetime('4-1-'+str(yr)):pd.to_datetime('10-31-'+str(yr))]
            winter = smoothed.loc[pd.to_datetime('10-1-'+str(yr)):pd.to_datetime('5-1-'+str(yr+1))]
            if len(summer)<0.9*7*30:
                maxval = np.nan
                maxdate = 1
            else:
                maxval = np.nanmax(summer)
                try:
                    maxdate = summer[summer==maxval].index.to_pydatetime()[0]
                    maxdate = maxdate.replace(year = 1900)
                except:
                    maxdate = 1
            if len(winter)<0.9*7*30:
                minval = np.nan
                mindate = 1
            else:
                minval = np.nanmin(winter)
                try:
                    mindate = winter[winter==minval].index.to_pydatetime()[0]
                    mindate = mindate.replace(year = 1900)
                except: 
                    mindate = 1
            maxtemp.append(maxval)
            mintemp.append(minval)
            maxdates.append(maxdate)
            mindates.append(mindate)
        median_max = np.nanmedian(maxtemp)
        median_min = np.nanmedian(mintemp)
        mindates = [x for x in mindates if x!=1]
        maxdates = [x for x in maxdates if x!=1]
        median_mindate = sorted(mindates)[len(mindates)//2]
        median_maxdate = sorted(maxdates)[len(maxdates)//2]

        # adjust min and max dates so they're exactly halfway different in year
        diff_maxmin = (median_maxdate-median_mindate).days
        startmin = median_mindate + pd.Timedelta((diff_maxmin-182)/2)
        startmax = median_maxdate - pd.Timedelta((diff_maxmin-182)/2)

        sinex = state_data_day.reset_index()['index'].dt.day.values
        startmin = startmin.replace(year = state_data.reset_index().datetimeUTC.dt.year[0])
        startdate = state_data.reset_index().datetimeUTC[0].to_pydatetime().timetuple().tm_yday
        offset = (91-(startmin).timetuple().tm_yday)+startdate
        amplitude = (median_max - median_min)/2
        state_data_day['baseflow_estimate'] = -amplitude*np.sin((sinex+offset)/182*np.pi)+amplitude+median_min
# Out:
# <AxesSubplot:>

# %%
state_data_day.columns
# Out:
# Index(['discharge_cfs', 'temperature_C', 'Tmin_water', 'Tmax_water', 'year',
#        'yday', 'dayl', 'prcp', 'srad', 'swe', 'tmax', 'tmin', 'vp',
#        'baseflow_estimate', 'E_bflow', 'E_flashflow', 'bflow_frac',
#        'flashflow_frac', 'btemp_from_air'],
#       dtype='object')

# %%
fig,ax = plt.subplots(3,figsize = (8,12))
ax0 = ax[0]
for col in performance_mean.columns:
    if col=='KGE':
        ax0.plot(BFI_vals,np.array([performance_mean[col].iloc[i][0] for i in range(len(performance_mean))])
                 ,label = col, lw = 2)
    else:
        normalize = np.nanmax(abs(performance_mean[col]))*np.sign(np.nanmedian(performance_mean[col]))
        ax0.plot(BFI_vals,performance_mean[col]/normalize,label = col, lw = 2)
ax0.set_title('performance mean')
ax0.legend()

ax0 = ax[1]
for col in performance_mean.columns:
    if col=='KGE':
        ax0.plot(BFI_vals,np.array([performance_max[col].iloc[i][0] for i in range(len(performance_mean))])
                 ,label = col, lw = 2)
    else:
        normalize = np.nanmax(abs(performance_max[col]))*np.sign(np.nanmedian(performance_max[col]))
        ax0.plot(BFI_vals,performance_max[col]/normalize,label = col, lw = 2)
ax0.set_title('performance_max')

ax0 = ax[2]
for col in performance_mean.columns:
    if col=='KGE':
        ax0.plot(BFI_vals,np.array([performance_min[col].iloc[i][0] for i in range(len(performance_mean))])
                 ,label = col, lw = 2)
    else:
        normalize = np.nanmax(abs(performance_min[col]))*np.sign(np.nanmedian(performance_min[col]))
        ax0.plot(BFI_vals,performance_min[col]/normalize,label = col, lw = 2)
ax0.set_title('performance min')
# Out:
# Text(0.5, 1.0, 'performance min')

# %%
plt.figure(figsize = (20,4))
# plt.fill_between(guessmin.index,guessmin,guessmax)
plt.plot(guessmin.index,guessmean,c='firebrick')
plt.fill_between(state_data_day.index, state_data_day.Tmin_water,
                state_data_day.Tmax_water)
